# %% [markdown]
# ## Analyzing zeros

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Functions

# %%
def max_con_zero(numbers):
  max_zeros = []
  max_temp = 0
  for i in numbers:
    if i == 0.0:
      max_temp += 1
    if i != 0.0:
      max_zeros.append(max_temp)
      max_temp = 0
  max_zeros.append(max_temp)
    
  return max(max_zeros)

# %%
def begin_con_zero(numbers):
  beg_zeros = 0
  for i in numbers:
    if i == 0.0:
      beg_zeros += 1
    else:
      return beg_zeros

# %%
def end_con_zero(numbers):
      return begin_con_zero(numbers[::-1])

# %% [markdown]
# # Load Data

# %%
dates = pd.date_range(start='2020-08', end='2022-10', freq="M")

# %%
data = pd.read_excel('/content/drive/MyDrive/07 - Six - Team only/Raw data copy/Time_Series_Merchants_Transactions_Anonymized.xlsx',)

# %%
data = data.set_index('Merchant Name')

# %%
data.columns = dates

# %%
data.head(3)
# Out:
#                2020-08-31  2020-09-30  2020-10-31  2020-11-30  2020-12-31  \
# Merchant Name
# Merchant 1       416772.0    395324.0    411329.0    475679.0    497747.0
# Merchant 2           21.0        24.0        13.0        21.0         4.0
# Merchant 3            1.0         1.0         0.0         0.0        50.0
#
#                2021-01-31  2021-02-28  2021-03-31  2021-04-30  2021-05-31  \
# Merchant Name
# Merchant 1       445429.0    505033.0    477349.0    496073.0    576800.0
# Merchant 2           80.0         1.0        24.0       183.0        31.0
# Merchant 3            3.0         4.0         4.0         0.0        16.0
#
#                ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# Merchant Name  ...
# Merchant 1     ...    644293.0    700144.0    611675.0    639038.0
# Merchant 2     ...        11.0       119.0        62.0        52.0
# Merchant 3     ...        50.0         0.0         0.0         0.0
#
#                2022-04-30  2022-05-31  2022-06-30  2022-07-31  2022-08-31  \
# Merchant Name
# Merchant 1       616915.0    686572.0    630707.0    622073.0    667523.0
# Merchant 2          432.0        86.0       108.0        72.0       101.0
# Merchant 3            0.0         0.0        49.0         1.0         1.0
#
#                2022-09-30
# Merchant Name
# Merchant 1       668189.0
# Merchant 2           80.0
# Merchant 3            0.0
#
# [3 rows x 26 columns]

# %% [markdown]
# # create data frame with number new columns for number of zeros, max cons zeros, cons zeroses at beginnnig and end

# %%
data_clean = data.copy(deep =True)

# %%
data['no_zero']=data_clean.eq(0).sum(axis=1)

max_cons_0 = []
for i in range(len(data)):
  max_cons_0.append(max_con_zero(data_clean.iloc[i].values))
data["cons_zeros"]=max_cons_0

cons_beg = []
for i in range(len(data)):
  cons_beg.append(begin_con_zero(data_clean.iloc[i].values))
data["begin_zeros"]=cons_beg

cons_end = []
for i in range(len(data)):
  cons_end.append(end_con_zero(data_clean.iloc[i].values))

data["end_zeros"]=cons_end

data_just_zeros = data[['no_zero','cons_zeros','begin_zeros','end_zeros']].copy(deep=True)

# %% [markdown]
# # saving files

# %%
#data_just_zeros.to_csv('/content/drive/MyDrive/07 - Six - Team only/Processed data/zero_features.csv')

# %%
#data.to_csv('/content/drive/MyDrive/07 - Six - Team only/Processed data/data_and_zero_features.csv')
