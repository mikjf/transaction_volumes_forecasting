# %% [markdown]
# # Magic

# %%
# !pip install pmdarima
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pmdarima
#   Downloading pmdarima-2.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 4.5 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.32)
# Collecting statsmodels>=0.13.2
#   Downloading statsmodels-0.13.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 27.8 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.21.6)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.3.5)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.13.2->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels>=0.13.2->pmdarima) (3.0.9)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# Successfully installed pmdarima-2.0.1 statsmodels-0.13.5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
from datetime import datetime
from pmdarima.arima import auto_arima
import tqdm

# %matplotlib inline

# %% [markdown]
# # Load & export data setup

# %%
# importing data

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import csv as source

data_source = '/content/drive/MyDrive/07 - Six - Team only/Processed data/ninetyfive.csv'

# %%
# export results as csv

output_dir = '/content/drive/MyDrive/Auto-ARIMA95/'

# %% [markdown]
# # Start & end data setup

# %%
# manually checked on data

data_start = '2020-08'
data_end = '2022-10'

# %%
dates = pd.date_range(start=data_start, end=data_end, freq='M')

# %% [markdown]
# # Final data ready to run

# %%
# importing data from data_source

data = pd.read_csv(data_source)

# %%
# resetting index

data = data.set_index('Merchant Name')

# %%
# setting dates as columns

data.columns = dates

# %%
# adding row for sum of monthly transactions

data.loc['total'] = data.sum()

# %%
data.tail(1)
# Out:
#                2020-08-31  2020-09-30  2020-10-31  2020-11-30  2020-12-31  \
# Merchant Name
# total           5814847.0   5329984.0   5388034.0   5878944.0   6833418.0
#
#                2021-01-31  2021-02-28  2021-03-31  2021-04-30  2021-05-31  \
# Merchant Name
# total           6007394.0   6102851.0   6053861.0   5713613.0   6571033.0
#
#                ...  2021-12-31  2022-01-31  2022-02-28  2022-03-31  \
# Merchant Name  ...
# total          ...   8079641.0   7202240.0   7248828.0   6936578.0
#
#                2022-04-30  2022-05-31  2022-06-30  2022-07-31  2022-08-31  \
# Merchant Name
# total           6711293.0   8313058.0   6785325.0   6882196.0   7599894.0
#
#                2022-09-30
# Merchant Name
# total           7321905.0
#
# [1 rows x 26 columns]

# %% [markdown]
# # Functions

# %%
def calc_error(y,y_hat,method='MAE', normalized=False):
  # y true values
  # y_hat predicted
  # method can be MAE or RMSE
  # normalized can be False, avarage, range, iqr
  if method == 'MAE':
    error_metric = np.mean((np.abs(y_hat - y)))
  else:
    error_metric = np.sqrt(np.mean((y_hat - y)**2))
  if normalized == False:
    return error_metric
  else:
    return normalize_error(y,error_metric,normalized)

# %%
def normalize_error(y,metric,method):
  # method = avarage, range, iqr
  if method == 'average':
    metric = metric/y.mean()
  elif method == 'range':
    metric = metric/(y.max()-y.min())
  else:
    metric = metric/scipy.stats.iqr(y)
  return metric

# %%
def run_arima(merchant, merchant_name):
  # merchant is a df created from row of a data frame we read
  merchant['month_index'] = merchant.index.month
  
  #train test split, since arima runs on min 21, we used that for train, and whatever is left for test
  train = pd.DataFrame({merchant_name : merchant[merchant_name][:21].values,
                      'Month' : merchant[merchant_name][:21].index})
  train = train.set_index('Month')
  train['month_index'] = train.index.month
  
  test = pd.DataFrame({merchant_name : merchant[merchant_name][21:].values,
                      'Month' : merchant[merchant_name][21:].index})
  test = test.set_index('Month')
  test['month_index'] = test.index.month
  
  # find best hyperparameters and fit the model
  model = auto_arima(train[[merchant_name]], exogenous=train[['month_index']],
                   start_p=1, 
                   max_p=3,
                   start_q=1, 
                   max_q=3,
                   d=None,
                   max_d=2,
                   start_P=1,
                   max_P=2,
                   start_Q=1,
                   max_Q=2,
                   D=1,
                   max_D=2,
                   m=12,  
                   seasonal=True,
                   test='adf',
                   trace=False,
                   error_action='ignore',  
                   suppress_warnings=True, 
                   stepwise=True)
  
  # validation: predict on the test data
  n_periods = len(test)
  df = train.copy(deep=True)
  
  fitted, confint = model.predict(n_periods=n_periods, 
                                  return_conf_int=True,
                                  exogenous=test[['month_index']])
  
  rmse = calc_error(test[merchant_name].values, fitted.values,method = 'RMSE')
  norm_rmse = calc_error(test[merchant_name].values, fitted.values,method = 'RMSE', normalized = 'range')
  
  # 12 month prediction
  # fit the model
  model_final = auto_arima(merchant[[merchant_name]], exogenous=merchant[['month_index']],
                           start_p=1, 
                           max_p=3,
                           start_q=1, 
                           max_q=3,
                           d=None,
                           max_d=2,
                           start_P=1,
                           max_P=2,
                           start_Q=1,
                           max_Q=2,
                           D=1,
                           max_D=2,
                           m=12,  
                           seasonal=True,
                           test='adf',
                           trace=False,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
  
  # time frame for forecasting
  forecast_df = pd.DataFrame({"month_index":pd.date_range(merchant.index[-1], periods = 12, freq='MS').month},
                    index = pd.date_range(merchant.index[-1] + pd.DateOffset(months=1), periods = 12, freq='MS'))
  
  prediction, confint_pred = model_final.predict(n_periods=12, 
                                        return_conf_int=True,
                                        exogenous=forecast_df[['month_index']])
  
  return prediction, confint_pred, rmse, norm_rmse

# %%
def run_all(data, dates, file_path):
  # data is the whole data frame
  # dates = time range in months

  # initializing necessary data
  data_predictions = pd.DataFrame({})
  data_CI_width = pd.DataFrame({})
  data_lower = pd.DataFrame({})
  data_upper = pd.DataFrame({})
  all_rmse = []
  all_norm_rmse = []
  crashes = []
  working = []

  # running auto ARIMA for every row
  for i in data.index:
    df = pd.DataFrame({str(i) : data.loc[i].values,
                       'Month' : dates})
    df['Month'] = pd.to_datetime(df['Month'],infer_datetime_format=True)
    df = df.set_index(['Month'])
    
    # try, except for the prevention if the auto ARIMA does not work
    # for some merchants
    try:
      predictions, CI, RMSE, norm_RMSE = run_arima(df, i)
      data_predictions[i] = predictions
      data_lower[i] = [item[0] for item in CI]
      data_upper[i] = [item[1] for item in CI]
      data_CI_width[i] = data_upper[i].values - data_lower[i].values
      all_rmse.append(RMSE)
      all_norm_rmse.append(norm_RMSE)
      working.append(i)
    except:
      crashes.append(i)

  # preparing the output data
  data_CI_width['Month'] = data_predictions.index
  data_lower['Month'] = data_predictions.index
  data_upper['Month'] = data_predictions.index
  
  data_CI_width = data_CI_width.set_index(['Month'])
  data_lower = data_lower.set_index(['Month'])
  data_upper = data_upper.set_index(['Month'])

  errors = pd.DataFrame({"Merchant":working,
                         'rmse':all_rmse,
                         'norm_rmse':all_norm_rmse})
  
  # saving the data to files
  data_predictions.to_csv(file_path+'data_predictions.csv')
  data_CI_width.to_csv(file_path+'data_CI_width.csv')
  data_lower.to_csv(file_path+'data_lower.csv')
  data_upper.to_csv(file_path+'data_upper.csv')
  errors.to_csv(file_path+'data_errors.csv')

  with open(file_path+'crashed.csv', 'w') as f:
    for line in crashes:
        f.write(f"{line}\n")

  return

# %%
def run_arima_with_plots(merchant, merchant_name, file_path):
  # merchant is a df created from row of a data frame we read
  merchant['month_index'] = merchant.index.month
  
  #train test split, since arima runs on min 21, we used that for train, and whatever is left for test
  train = pd.DataFrame({merchant_name : merchant[merchant_name][:21].values,
                      'Month' : merchant[merchant_name][:21].index})
  train = train.set_index('Month')
  train['month_index'] = train.index.month
  
  test = pd.DataFrame({merchant_name : merchant[merchant_name][21:].values,
                      'Month' : merchant[merchant_name][21:].index})
  test = test.set_index('Month')
  test['month_index'] = test.index.month
  
  # find best hyperparameters and fit the model
  model = auto_arima(train[[merchant_name]], exogenous=train[['month_index']],
                   start_p=1, 
                   max_p=3,
                   start_q=1, 
                   max_q=3,
                   d=None,
                   max_d=2,
                   start_P=1,
                   max_P=2,
                   start_Q=1,
                   max_Q=2,
                   D=1,
                   max_D=2,
                   m=12,  
                   seasonal=True,
                   test='adf',
                   trace=False,
                   error_action='ignore',  
                   suppress_warnings=True, 
                   stepwise=True)
  
  # validation: predict on the test data
  n_periods = len(test)
  df = train.copy(deep=True)
  
  fitted, confint = model.predict(n_periods=n_periods, 
                                  return_conf_int=True,
                                  exogenous=test[['month_index']])
  
  rmse = calc_error(test[merchant_name].values, fitted.values,method = 'RMSE')
  norm_rmse = calc_error(test[merchant_name].values, fitted.values,method = 'RMSE', normalized = 'range')
  
  # 12 month prediction
  # fit the model
  model_final = auto_arima(merchant[[merchant_name]], exogenous=merchant[['month_index']],
                           start_p=1, 
                           max_p=3,
                           start_q=1, 
                           max_q=3,
                           d=None,
                           max_d=2,
                           start_P=1,
                           max_P=2,
                           start_Q=1,
                           max_Q=2,
                           D=1,
                           max_D=2,
                           m=12,  
                           seasonal=True,
                           test='adf',
                           trace=False,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
  
  # time frame for forecasting
  forecast_df = pd.DataFrame({"month_index":pd.date_range(merchant.index[-1], periods = 12, freq='MS').month},
                    index = pd.date_range(merchant.index[-1] + pd.DateOffset(months=1), periods = 12, freq='MS'))
  
  prediction, confint_pred = model_final.predict(n_periods=12, 
                                        return_conf_int=True,
                                        exogenous=forecast_df[['month_index']])
  
  ################################################
  # Plot - just to check at the beginning
  
  # make series for plotting purpose
  lower_series = pd.Series(confint[:, 0], index=test.index)
  upper_series = pd.Series(confint[:, 1], index=test.index)
  
  plt.figure(figsize=(15,7))
  plt.plot(df[merchant_name], color='#1f76b4')
  plt.plot(fitted, color='darkgreen')
  plt.plot(test[merchant_name], color='#1f76b4')
  plt.fill_between(lower_series.index, 
                  lower_series, 
                  upper_series, 
                  color='k', alpha=.15)
  
  plt.title("Train-Test validation for "+str(merchant_name))
  #plt.show()
  # here save, instead of show
  # name by merchants
  #plt.draw()
  plt.savefig(file_path+'train_test_'+str(merchant_name)+'.png')
  
  print('Test RMSE: %.3f' % rmse)
  
  # Plot prediction
  index_of_fc = pd.date_range(merchant.index[-1] + pd.DateOffset(months=1), periods = 12, freq='MS')
  
  # make series for plotting purpose
  lower_series = pd.Series(confint_pred[:, 0], index=index_of_fc)
  upper_series = pd.Series(confint_pred[:, 1], index=index_of_fc)
  
  # Plot
  plt.figure(figsize=(15,7))
  plt.plot(merchant[merchant_name], color='#1f76b4')
  plt.plot(prediction, color='darkgreen')
  plt.fill_between(lower_series.index, 
                  lower_series, 
                  upper_series, 
                  color='k', alpha=.15)
  
  plt.title("Forecast of Transactions for "+str(merchant_name))
  #plt.show()
  #plt.draw()
  plt.savefig(file_path+'forecast_'+str(merchant_name)+'.png')
##################################################

  
  return prediction, confint_pred, rmse, norm_rmse

# %%
def run_all_with_plots(data, dates, file_path):
  # data is the whole data frame
  # dates = time range in months

  # initializing necessary data
  data_predictions = pd.DataFrame({})
  data_CI_width = pd.DataFrame({})
  data_lower = pd.DataFrame({})
  data_upper = pd.DataFrame({})
  all_rmse = []
  all_norm_rmse = []
  crashes = []
  working = []

  # running auto ARIMA for every row
  for i in data.index:
    df = pd.DataFrame({str(i) : data.loc[i].values,
                       'Month' : dates})
    df['Month'] = pd.to_datetime(df['Month'],infer_datetime_format=True)
    df = df.set_index(['Month'])
    
    # try, except for the prevention if the auto ARIMA does not work
    # for some merchants
    try:
      predictions, CI, RMSE, norm_RMSE = run_arima_with_plots(df, i, file_path)
      data_predictions[i] = predictions
      data_lower[i] = [item[0] for item in CI]
      data_upper[i] = [item[1] for item in CI]
      data_CI_width[i] = data_upper[i].values - data_lower[i].values
      all_rmse.append(RMSE)
      all_norm_rmse.append(norm_RMSE)
      working.append(i)
    except:
      crashes.append(i)

  # preparing the output data
  data_CI_width['Month'] = data_predictions.index
  data_lower['Month'] = data_predictions.index
  data_upper['Month'] = data_predictions.index
  
  data_CI_width = data_CI_width.set_index(['Month'])
  data_lower = data_lower.set_index(['Month'])
  data_upper = data_upper.set_index(['Month'])

  errors = pd.DataFrame({"Merchant":working,
                         'rmse':all_rmse,
                         'norm_rmse':all_norm_rmse})
  
  # saving the data to files
  data_predictions.to_csv(file_path+'data_predictions.csv')
  data_CI_width.to_csv(file_path+'data_CI_width.csv')
  data_lower.to_csv(file_path+'data_lower.csv')
  data_upper.to_csv(file_path+'data_upper.csv')
  errors.to_csv(file_path+'data_errors.csv')

  with open(file_path+'crashed.csv', 'w') as f:
    for line in crashes:
        f.write(f"{line}\n")

  return

# %% [markdown]
# # How it runs

# %%
# 12 months predictions
# CI dataframes created in output dir
# RSME and RSME/range output in data_errors.csv
# list of "errors" merchant list due to auto-ARIMA with the current setup in output crashed.csv

# %% [markdown]
# # Auto-ARIMA ready

# %%
# to run for selected rows

#run_all(data.iloc[:2], dates, output_dir)

# %%
# to run for all rows

#run_all(data, dates, output_dir)

# %% [markdown]
# ## Row 'total'

# %%
# with plots for 'total' row (last row == sum of merchants)

# %%time

run_all_with_plots(data.iloc[-1:], dates, output_dir)
# Out:
# Test RMSE: 536778.768
# CPU times: user 4.59 s, sys: 3.99 s, total: 8.58 s
# Wall time: 7.87 s

# %% [markdown]
# ## All rows

# %%
# with plots for each row 1 by 1

# %%time

run_all_with_plots(data, dates, output_dir)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
